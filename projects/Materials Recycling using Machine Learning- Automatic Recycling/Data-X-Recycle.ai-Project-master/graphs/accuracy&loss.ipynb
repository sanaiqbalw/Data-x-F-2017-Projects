# %% [markdown]
# # Plots of Model Accuracy/Loss

# %%
# Fine-tuned Inception Model
fti_vals={'val_loss': [0.68165370451437457, 0.68694769562901681, 0.67316757569441921, 0.57439061467711994, 0.74448735262896559, 0.81313232731174778, 0.70533253051139211, 0.7710098356813998, 0.76403486148731126, 0.71544762688714103, 0.74301181596678656, 0.84909382446392168, 0.72130927588488603, 0.86624628571239681, 0.97151754015200842, 0.96069295084154283, 0.82283592578527087, 0.64161160330514655, 1.0323838884766037, 0.82931617772257005], 'val_acc': [0.7567567593342549, 0.75675675997862946, 0.77567567632005019, 0.80270270463582627, 0.76756756692319306, 0.78108107979233199, 0.79459459523896914, 0.80000000032218732, 0.80000000064437449, 0.78648648584211189, 0.81351351415788808, 0.79189189124751735, 0.83243243436555603, 0.79999999871125094, 0.77837838160025108, 0.80540540476103084, 0.84324324356543057, 0.83243243275461976, 0.77297297232859841, 0.82702702734921429], 'acc': [0.81092436974789917, 0.86470588255329295, 0.88697479011631808, 0.9138655464188391, 0.94243697489009182, 0.94201680682286493, 0.95630252120875514, 0.95840336144471372, 0.96974789925983973, 0.96596638655462186, 0.96680672268907564, 0.97689075630252098, 0.98109243697478987, 0.97605042036841894, 0.97563025220101618, 0.98319327731092432, 0.98109243697478987, 0.98277310934387341, 0.9840336134453781, 0.98151260514219263], 'loss': [0.52138299360996532, 0.37089443797824762, 0.32141504598264936, 0.25527498441583968, 0.17627540741647993, 0.17355384959393189, 0.13101003335303618, 0.12036124282524366, 0.099835355579853055, 0.10332949761958683, 0.097887344094885503, 0.065450164149789256, 0.062055884451926252, 0.073661019631168417, 0.065908300637134487, 0.055601116153998535, 0.064878103425021927, 0.052308572864770392, 0.043160930432441853, 0.059816253415363674]}

fti_val_loss = fti_vals.get('val_loss')
fti_val_acc = fti_vals.get('val_acc')
fti_loss = fti_vals.get('loss')
fti_acc = fti_vals.get('acc')

# %%
len(fti_val_loss)
# Out:
# 20

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.plot(range(1,21),fti_val_acc, color = 'r', label = 'validation')
plt.plot(range(1,21),fti_acc, color = 'b', label = 'training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0.6,1)
plt.title('Fine-Tuned InceptionV3 Accuracy')
plt.legend()

# %%
plt.plot(range(1,21),fti_val_loss, color = 'r', label = 'validation')
plt.plot(range(1,21),fti_loss, color = 'b', label = 'training')
plt.xlabel('Epochs')
plt.ylabel('Loss',)
plt.title('Fine-Tuned Inception CNN Loss')
plt.legend()

# %%
print(fti_val_loss)
# Out:
# [0.6816537045143746, 0.6869476956290168, 0.6731675756944192, 0.5743906146771199, 0.7444873526289656, 0.8131323273117478, 0.7053325305113921, 0.7710098356813998, 0.7640348614873113, 0.715447626887141, 0.7430118159667866, 0.8490938244639217, 0.721309275884886, 0.8662462857123968, 0.9715175401520084, 0.9606929508415428, 0.8228359257852709, 0.6416116033051465, 1.0323838884766037, 0.82931617772257]

# %%
basic_vals = {'val_acc': [0.265625, 0.32552083333333331, 0.3828125, 0.40885416666666669, 0.47135416666666669, 0.43489583333333331, 0.4609375, 0.47135416666666669, 0.546875, 0.5390625, 0.54947916666666663, 0.5625, 0.5546875, 0.609375, 0.55989583333333337, 0.625, 0.6015625, 0.6328125, 0.59635416666666663, 0.63802083333333337], 'val_loss': [1.6532386144002278, 1.4975773294766743, 1.4894329508145649, 1.3364596863587697, 1.2737246751785278, 1.3616108099619548, 1.2904801666736603, 1.3330500920613606, 1.1682448138793309, 1.220112254222234, 1.2616819938023884, 1.2131587415933609, 1.254144807656606, 1.062995473543803, 1.1322822471459706, 1.0608609070380528, 1.1683976749579112, 1.067960153023402, 1.2155867765347164, 1.0905953943729401], 'acc': [0.26864919354838712, 0.35030549898167007, 0.42668024452057973, 0.47352342170998907, 0.50203665987780044, 0.55745967741935487, 0.56720977602811062, 0.62474541775806369, 0.62576374769696397, 0.65987780040733202, 0.6634419551934827, 0.70161290322580649, 0.69602851335968363, 0.73268839116009088, 0.75050916521223887, 0.74745417527414393, 0.75661914484564008, 0.77973790322580649, 0.77494908362444936, 0.8060081467609056], 'loss': [1.7206805444532824, 1.578160815229241, 1.4496500715461622, 1.3585912831689093, 1.2697008571411101, 1.1859573048930014, 1.1242920245269652, 1.0461615408996459, 0.98529605066703441, 0.91457886280693013, 0.92657841975722921, 0.8265172233504634, 0.82689453033225846, 0.75000851824424419, 0.70152945637460151, 0.70013315869445958, 0.65962225077351344, 0.62323436429423673, 0.60139132954195418, 0.54924452493001386]}
basic_val_loss = basic_vals.get('val_loss')
basic_val_acc = basic_vals.get('val_acc')
basic_loss = basic_vals.get('loss')
basic_acc = basic_vals.get('acc')

# %%
plt.plot(range(1,21),basic_val_loss, color = 'r', label = 'validation')
plt.plot(range(1,21),basic_loss, color = 'b', label = 'training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Basic CNN Loss')
plt.legend()

# %%
plt.plot(range(1,21),basic_val_acc, color = 'r', label = 'validation')
plt.plot(range(1,21),basic_acc, color = 'b', label = 'training')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Basic CNN Accuracy')
plt.legend()

# %% [markdown]
# # Gerry Model Improved

# %%
gerry_val_acc = [0.5498,0.7189,0.7463,0.6667,0.709,0.7488,0.7836,0.7612,0.7861,0.7537,0.7711,0.6965,0.7612,0.7687,0.7687,0.7861,0.7861,0.7836,0.7811,0.7836,0.7811,0.8035,0.7637,0.7612,0.7687,0.709,0.7836,0.7587,0.7761,0.7711,0.7861,0.7562,0.709,0.7338,0.7786,0.791,0.7761,0.806,0.7761,0.7761]
gerry_acc = [0.521,0.7776,0.841,0.8795,0.9024,0.9338,0.9467,0.9557,0.9662,0.969,0.9752,0.97,0.9629,0.9676,0.9781,0.9838,0.9829,0.9867,0.9929,0.9719,0.9886,0.9867,0.9905,0.9919,0.9895,0.9871,0.9876,0.9876,0.9886,0.9933,0.9867,0.9819,0.981,0.9786,0.9814,0.9819,0.9805,0.9776,0.9743,0.9833
]


plt.plot(range(1,41),gerry_val_acc, color = 'r', label = 'validation')
plt.plot(range(1,41),gerry_acc, color = 'b', label = 'training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Trained Top CNN Accuracy')
plt.legend()

# %% [markdown]
# ## Kenny's Final Models

# %%
# FineTuned model
final_fine = {'categorical_accuracy': [0.75630252110857921, 0.84789915966386553, 0.90924369757916745, 0.93865546228504981, 0.94663865566253658, 0.95504201690689861, 0.95882352961211648, 0.95924369747899163, 0.96596638655462186, 0.96512605052034395, 0.97016806732706662, 0.97815126070455338, 0.9747899160665624, 0.98613445398186439, 0.97352941186488173, 0.97899159663865543, 0.98277310934387341, 0.98235294127664641, 0.9760504201680672, 0.9844537815126051, 0.9869747900161423, 0.98361344547832719, 0.98865546238522573, 0.98739495798319332, 0.99285714285714288, 0.9882352941176471, 0.9840336134453781, 0.99033613445378155, 0.99285714295731875, 0.99117647068841119], 'val_categorical_accuracy': [0.67297297232859843, 0.78918919176668734, 0.79729729794167181, 0.83513513513513515, 0.81621621557184165, 0.80000000193312359, 0.80270270431363899, 0.8108108114551853, 0.82702702896015068, 0.84594594787906952, 0.83783783977096149, 0.81891891956329343, 0.76756756950069116, 0.80000000161093632, 0.79189189350282829, 0.81621621653840348, 0.8135135151244498, 0.81621621686059076, 0.82702702896015068, 0.82432432625744789, 0.79729729923042092, 0.82162162194380894, 0.84594594659032052, 0.84054054247366417, 0.8486486505817723, 0.85405405469842854, 0.82432432464651162, 0.82702702767140157, 0.83783783848221238, 0.85945945978164673], 'val_loss': [1.0822142356150859, 0.7826818272874162, 0.71962177850104669, 0.61929414699206486, 0.64929897849624219, 0.77355081326252706, 0.94390937653747764, 0.85362186689634578, 0.74075356625221866, 0.65319782269967563, 0.75189082976934074, 0.76158527748004812, 1.0216107776036134, 0.86516542764934334, 1.0961976502392743, 0.91284769080780648, 0.86101982448552106, 0.78852391178543502, 0.84447337936710665, 1.0320505496617911, 1.0131032734303862, 0.77748668693207401, 0.75220469977404625, 0.88780469958846631, 0.80813754442575814, 0.75034868201693972, 1.0447891116142274, 0.87975968025826123, 0.85693792298033433, 0.66306687955920762], 'loss': [0.71128030344217763, 0.43696361740096279, 0.27732342942422178, 0.19861653562353437, 0.141425462254957, 0.15944605379545387, 0.12867151354791737, 0.13590760873082805, 0.10000844284297288, 0.11321358913634004, 0.097273032617669147, 0.06554810471144043, 0.07532023855038926, 0.058007068775531627, 0.077377847286269952, 0.066025863605856647, 0.04779280459688303, 0.06217742730323382, 0.077805749569166485, 0.040752877106796169, 0.038227557138532021, 0.0720997400394007, 0.038155197514956739, 0.038839877475867, 0.019578303845145372, 0.034044320992303687, 0.054050704130918538, 0.03487181346393934, 0.023866491354688876, 0.029968605415324267]}

# %%
max(final_fine.get('val_categorical_accuracy'))
# Out:
# 0.8594594597816467

# %%
plt.plot(range(1,31),final_fine.get('val_categorical_accuracy'), color = 'r', label = 'validation')
plt.plot(range(1,31),final_fine.get('categorical_accuracy'), color = 'b', label = 'training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0.3,1)
plt.title('Fine-Tuned InceptionV3 Accuracy')
plt.legend(loc=4)

# %%
plt.plot(range(1,31),final_fine.get('loss'), color = 'b', label = 'training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Trained Top CNN Loss')
plt.legend()

# %%
# Trained Top Model

# %%
# Training top model
final_top = {'categorical_accuracy': [0.38991596648673049, 0.58865546218487397, 0.65588235304135234, 0.66974789915966382, 0.72436974799933551, 0.72268907583060382, 0.70924369767934337, 0.76428571438589021, 0.76680672288942742, 0.79705882362958769, 0.78529411784741054, 0.7882352942178229, 0.79159663865546215, 0.80210084053648623, 0.79747899169681458, 0.81596638655462184, 0.82605042036841902, 0.83655462204909126, 0.83277310924369752, 0.84075630272136015, 0.84033613465413326, 0.85672268927598205, 0.85336134453781509, 0.84537815136068006, 0.83193277310924374, 0.86050420168067232, 0.87647058823529411, 0.87226890756302522, 0.86176470598252886, 0.88277310924369745], 'val_categorical_accuracy': [0.5703125, 0.58108108204764286, 0.63513513610169692, 0.68648648777523558, 0.72162162097724714, 0.662162163128724, 0.67027026962589575, 0.68378378571690734, 0.65405405469842859, 0.67027027284776841, 0.67837838095587655, 0.67027027284776841, 0.69999999999999996, 0.67027027188120658, 0.70810810907466992, 0.72162162194380886, 0.7621621628065367, 0.70810810746373354, 0.6972972998747955, 0.73243243436555605, 0.73513513577950962, 0.77567567632005019, 0.68108108236983012, 0.71351351448007527, 0.72702702831577615, 0.71621621621621623, 0.73513513449076062, 0.74054054118491508, 0.71891891988548073, 0.70270270366926446], 'val_loss': [1.2025253226359685, 1.0742974094442419, 0.99242220440426387, 0.83965419079806358, 0.84648314521119405, 0.97672106124259328, 0.93662139016228751, 0.96444791716498302, 0.92409079171515796, 0.86723696025642194, 0.87439140757998901, 0.92758925734339537, 0.78005734778739311, 0.9621198776605967, 0.80429870051306651, 0.84229959475027549, 0.81537608198217448, 0.86883607104017924, 0.91606757286432627, 0.8886615398767832, 0.79863652506390137, 0.82382069858344831, 1.0558496610538379, 0.87366219082394159, 0.8314625311542202, 0.88104788419362656, 0.82086550738360431, 0.84865034464243294, 0.89866940395252126, 0.96558022627959383], 'loss': [1.5006434398538926, 1.0881024412748193, 0.90280616784296119, 0.89251061898319661, 0.78340101116845584, 0.75809117886198674, 0.77490549277858578, 0.64976127929046379, 0.63904400212424139, 0.59745743795603268, 0.61840849183186763, 0.5725455656772902, 0.58821155894704225, 0.54920839301678315, 0.54342362860671611, 0.50974531494268849, 0.48274799585342409, 0.46014829673686947, 0.4520964594448314, 0.45989379351880372, 0.45429933501892733, 0.39953695465536676, 0.42022342581708894, 0.43039347223874902, 0.43680035547048102, 0.39611418908383667, 0.35632592745187902, 0.35034281416099611, 0.38322793916493902, 0.34545511523214711]}

# %%
final_top.get('val_categorical_accuracy')
# Out:
# [0.5703125,
#  0.5810810820476429,
#  0.6351351361016969,
#  0.6864864877752356,
#  0.7216216209772471,
#  0.662162163128724,
#  0.6702702696258958,
#  0.6837837857169073,
#  0.6540540546984286,
#  0.6702702728477684,
#  0.6783783809558765,
#  0.6702702728477684,
#  0.7,
#  0.6702702718812066,
#  0.7081081090746699,
#  0.7216216219438089,
#  0.7621621628065367,
#  0.7081081074637335,
#  0.6972972998747955,
#  0.732432434365556,
#  0.7351351357795096,
#  0.7756756763200502,
#  0.6810810823698301,
#  0.7135135144800753,
#  0.7270270283157761,
#  0.7162162162162162,
#  0.7351351344907606,
#  0.7405405411849151,
#  0.7189189198854807,
#  0.7027027036692645]

# %%
plt.plot(range(1,31),final_top.get('val_categorical_accuracy'), color = 'r', label = 'validation')
plt.plot(range(1,31),final_top.get('categorical_accuracy'), color = 'b', label = 'training')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0.3,1)
plt.title('Top Trained InceptionV3 Accuracy')
plt.legend(loc = 4)
